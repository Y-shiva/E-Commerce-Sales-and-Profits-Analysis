# %% [markdown]
# <a href="https://colab.research.google.com/github/Y-shiva/E-Commerce-Sales-and-Profits-Analysis/blob/main/Super%20Store%20data%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data Exploration and Cleaning

# %% [markdown]
# Question 1.1: Load the dataset into a Pandas DataFrame.

# %%
super_store_df = pd.read_csv('/content/Sample - Superstore (1).csv', encoding='latin1')
super_store_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# Question 1.1: Display the first 5 rows and check for missing values.

# %%
super_store_df.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Shape of the data set
super_store_df.shape
# Out:
# (9994, 21)

# %%
# columns in the dataset
super_store_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# mean, median,mode,avg,min,max values for the numeric columns
super_store_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# Question 1.2: Are there any null values in the dataset? If yes, remove them.

# %%
super_store_df.isnull().sum() # Getting the sum of null values for each column
super_store_df.dropna(how = "all",inplace = True) # Removing the null values
super_store_df.isnull().sum() # Checking the null values again
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Question 1.3: Are there any  duplicates rows in the dataset? If yes, remove them.

# %%
super_store_df.duplicated().sum()    # Getting the sum of duplicates for the dataset.
super_store_df.drop_duplicates(inplace = True) # Removing the duplicates
super_store_df.duplicated().sum() # Checking the duplicates again
# Out:
# 0

# %% [markdown]
# Question 1.3: What are the data types of each column?

# %%
super_store_df.info() # Getting the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Convert the Order Date and Ship Date columns to datetime format
super_store_df['Order Date'] = pd.to_datetime(super_store_df['Order Date'])
super_store_df['Ship Date'] = pd.to_datetime(super_store_df['Ship Date'])

# %%
super_store_df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # 2. Basic Analysis

# %% [markdown]
# Question 2.1: What is the total number of orders, total sales, and total profit in the dataset?

# %%
number_orders = super_store_df['Order ID'].nunique()
number_orders                 # Total number orders
# Out:
# 5009

# %%
Total_sales = super_store_df['Sales'].sum()
Total_sales.round(2)              # Total Sales
# Out:
# 2297200.86

# %%
Total_Profit = super_store_df['Profit'].sum()
Total_Profit.round(2)             # Total Profit
# Out:
# 286397.02

# %% [markdown]
# Question 2.2: Which customer segment (Segment) has the highest number of orders? Visualize this using a bar chart.

# %%
segment_orders = super_store_df.groupby('Segment')['Order ID'].nunique().sort_values(ascending = False)
print(segment_orders , 'segment_orders')
# Out:
# Segment
# Consumer       2586
# Corporate      1514
# Home Office     909
# Name: Order ID, dtype: int64 segment_orders

# %%
# Plot number of orders by segment
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']
plt.bar(segment_orders.index, segment_orders.values,color = colors)
plt.xlabel('Segment')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Segmentnt')
plt.show()

# %%
region_orders = super_store_df.groupby('Region')['Order ID'].nunique().sort_values(ascending = False)
print(region_orders , 'region_orders')
# Out:
# Region
# West       1611
# East       1401
# Central    1175
# South       822
# Name: Order ID, dtype: int64 region_orders

# %%
colors = ['red','green','blue','purple']
plt.bar(region_orders.index,region_orders.values,color = colors)
plt.xlabel('Region')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Region')
plt.show()

# %% [markdown]
# # 3. Time-Based Analysis

# %%
super_store_df['Year'] = super_store_df['Order Date'].dt.year
sum_of_sales_per_year = super_store_df.groupby('Year')['Sales'].sum()
sum_of_sales_per_year = pd.DataFrame(sum_of_sales_per_year)
sum_of_sales_per_year
# Out:
#             Sales
# Year
# 2014  484247.4981
# 2015  470532.5090
# 2016  609205.5980
# 2017  733215.2552

# %%
sum_of_profit_per_year = super_store_df.groupby('Year')['Profit'].sum()
sum_of_profit_per_year = pd.DataFrame(sum_of_profit_per_year)
sum_of_profit_per_year
# Out:
#           Profit
# Year
# 2014  49543.9741
# 2015  61618.6037
# 2016  81795.1743
# 2017  93439.2696

# %%
# Set up the figure and axis
plt.figure(figsize=(10, 6))

# Plot total sales over the years
plt.plot(sum_of_sales_per_year.index, sum_of_sales_per_year['Sales'], marker='o', label='Total Sales', color='blue')

# Plot total profit over the years
plt.plot(sum_of_profit_per_year.index, sum_of_profit_per_year['Profit'], marker='o', label='Total Profit', color='brown')

# Add titles and labels
plt.title('Total Sales and Profit Over the Years')
plt.xlabel('Year')
plt.ylabel('Amount ($)')
plt.legend()

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Question 3.2: Which month has the highest number of orders? Create a bar chart to visualize monthly order counts.

# %%
# Extract the month names from the 'Order Date' column
super_store_df['Month'] = super_store_df['Order Date'].dt.month_name()

# Group by 'Month' and count the unique 'Order ID', then sort by the month order
monthly_oders = (
    super_store_df.groupby('Month')['Order ID']
    .nunique()
    .sort_index(key=lambda x: pd.to_datetime(x, format='%B').month)
)

# Print the result with a proper new line character
print(monthly_oders, '\n')
# Out:
# Month
# January      178
# February     162
# March        354
# April        343
# May          369
# June         364
# July         338
# August       341
# September    688
# October      417
# November     753
# December     702
# Name: Order ID, dtype: int64

# %%
plt.bar(monthly_oders.index,monthly_oders.values)
plt.xlabel('Month')
plt.xticks(rotation = 45)
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Month')
plt.show()

# %% [markdown]
# Question 3.3: What is the average shipping time (Ship Date - Order Date) in days? Plot a histogram of shipping times.

# %%
shipping_days = (super_store_df['Ship Date'] - super_store_df['Order Date']).dt.days
average_shipping_days  = shipping_days.mean()
average_shipping_days.round(2)
# Out:
# 3.96

# %%
# Set up the figure and axis
plt.figure(figsize=(10, 6))

# Plot the histogram of shipping times
plt.hist(average_shipping_days, bins=30, color='orange', edgecolor='black')

# Add titles and labels
plt.title('Distribution of Shipping Times')
plt.xlabel('Shipping Time (Days)')
plt.ylabel('Frequency')

# Display the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Product and Category Analysis

# %% [markdown]
# Question 4.1: Which product category (Category) has the highest sales and profit? Visualize this using a bar chart.

# %%
category_sales = super_store_df.groupby('Category')['Sales'].sum()
category_sales = pd.DataFrame(category_sales).reset_index()
category_sales
# Out:
#           Category        Sales
# 0        Furniture  741999.7953
# 1  Office Supplies  719047.0320
# 2       Technology  836154.0330

# %%
category_profit = super_store_df.groupby('Category')['Profit'].sum()
category_profit = pd.DataFrame(category_profit).reset_index()
category_profit

category_sales_and_profits = pd.merge(category_sales,category_profit,on = 'Category')
category_sales_and_profits
# Out:
#           Category        Sales       Profit
# 0        Furniture  741999.7953   18451.2728
# 1  Office Supplies  719047.0320  122490.8008
# 2       Technology  836154.0330  145454.9481

# %%
plt.figure(figsize=(10,6))
fig,ax1= plt.subplots()
ax2 = ax1.twinx()
ax1.bar(category_sales_and_profits['Category'],category_sales_and_profits['Profit'],color='green')
ax2.plot(category_sales_and_profits['Category'],category_sales_and_profits['Sales'], color = 'orange')

ax1.set_xlabel('Category')
ax1.set_ylabel('Profit')
ax2.set_ylabel('Sales')
plt.title('Sales and Profit by Category')
plt.legend()
plt.show()
# Out:
# <ipython-input-31-62e6b95f9533>:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Question 4.2: What are the top 10 products by sales? Create a bar chart to display them.

# %%
super_store_df.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
top_products = super_store_df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

top_products = pd.DataFrame(top_products).reset_index()
top_products
# Out:
#                                         Product Name      Sales
# 0              Canon imageCLASS 2200 Advanced Copier  61599.824
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.384
# 2  Cisco TelePresence System EX90 Videoconferenci...  22638.480
# 3       HON 5400 Series Task Chairs for Big and Tall  21870.576
# 4         GBC DocuBind TL300 Electric Binding System  19823.479
# 5   GBC Ibimaster 500 Manual ProClick Binding System  19024.500
# 6               Hewlett Packard LaserJet 3310 Copier  18839.686
# 7  HP Designjet T520 Inkjet Large Format Printer ...  18374.895
# 8          GBC DocuBind P400 Electric Binding System  17965.068
# 9        High Speed Automatic Electric Letter Opener  17030.312

# %%
plt.bar(top_products['Product Name'],top_products['Sales'])
plt.xlabel('Product Name')
plt.ylabel('Sales')
plt.title('Top 10 Products by Sales')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Question 4.3: Which sub-category (Sub-Category) has the highest average discount? Visualize this using a bar chart.

# %%
sub_category = super_store_df.groupby('Sub-Category')['Discount']
highest_average_discount = sub_category.mean().sort_values(ascending = False)
highest_average_discount = pd.DataFrame(highest_average_discount).reset_index()
highest_average_discount
# Out:
#    Sub-Category  Discount
# 0       Binders  0.372292
# 1      Machines  0.306087
# 2        Tables  0.261285
# 3     Bookcases  0.211140
# 4        Chairs  0.170178
# 5    Appliances  0.166524
# 6       Copiers  0.161765
# 7        Phones  0.154556
# 8   Furnishings  0.138349
# 9     Fasteners  0.082028
# 10    Envelopes  0.080315
# 11  Accessories  0.078452
# 12     Supplies  0.076842
# 13        Paper  0.074891
# 14          Art  0.074874
# 15      Storage  0.074704
# 16       Labels  0.068681

# %%
plt.bar(highest_average_discount['Sub-Category'],highest_average_discount['Discount'])
plt.xlabel('Sub-Category')
plt.ylabel('Average Discount')
plt.title('Average Discount by Sub-Category')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # 5. Customer Analysis

# %% [markdown]
# Question 5.1: Who are the top 5 customers by total sales? Create a bar chart to display them.

# %%
customer_sales = super_store_df.groupby('Customer Name')['Sales'].sum().sort_values(ascending = False)
Top5_customers = customer_sales.head(5)
Top5_customers
# Out:
# Customer Name
# Sean Miller      25043.050
# Tamara Chand     19052.218
# Raymond Buch     15117.339
# Tom Ashbrook     14595.620
# Adrian Barton    14473.571
# Name: Sales, dtype: float64

# %%
colors = ['green','blue','yellow','orange','purple']
plt.bar(Top5_customers.index,Top5_customers.values, color = colors )
plt.xlabel('Customer Name')
plt.ylabel('Sales')
plt.title('Top 5 Customers by Sales')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Question 5.2: What is the distribution of customers across different regions? Use a pie chart to visualize this.

# %%
region_customers =super_store_df.groupby('Region')['Customer ID'].count()
print(region_customers, '/n')
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# Name: Customer ID, dtype: int64 /n

# %%
plt.pie(region_customers,labels = region_customers.index,autopct = '%1.1f%%',startangle = 140)
plt.title('Distribution of Customers Across Different Regions')
plt.show()

# %% [markdown]
# Question 5.3: Which customer has the highest average profit per order?

# %%
customer = super_store_df.groupby('Customer Name')['Profit'].mean().sort_values(ascending = False)
customer.head(1)
# Out:
# Customer Name
# Tamara Chand    748.443658
# Name: Profit, dtype: float64

# %% [markdown]
# # 6.Shipping Mode Analysis

# %% [markdown]
# Question 6.1: Which shipping mode (Ship Mode) is the most popular? Visualize this using a bar chart.

# %%
Ship_Mode = super_store_df.groupby('Ship Mode')['Order ID'].count()
Ship_Mode
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# Name: Order ID, dtype: int64

# %%
plt.bar(Ship_Mode.index,Ship_Mode.values)
plt.xlabel('Ship Mode')
plt.ylabel('Orders Count')
plt.title('Numbers of Orders By Each Ship Mode')
plt.show()

# %% [markdown]
# Question 6.2: Which shipping mode generates the highest profit?

# %%
ship_mode_profit = super_store_df.groupby('Ship Mode')['Profit'].sum().sort_values(ascending = False)
ship_mode_profit.round(0)
# Out:
# Ship Mode
# Standard Class    164089.0
# Second Class       57447.0
# First Class        48970.0
# Same Day           15892.0
# Name: Profit, dtype: float64

# %%
plt.bar(ship_mode_profit.index,ship_mode_profit.values)
plt.xlabel('Ship Mode')
plt.ylabel('Orders Count')
plt.title('Numbers of Orders By Each Ship Mode')
plt.show()

# %%
super_store_df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %% [markdown]
# # 7. Profit Analysis

# %% [markdown]
# Question 7.1: Are there any seasonal trends in sales or profit? Plot a line graph to analyze monthly trends.

# %%
each_month_profits = super_store_df.groupby('Month')['Profit'].sum().sort_index(key=lambda x: pd.to_datetime(x, format='%B').month)
each_month_profits.round(2)
# Out:
# Month
# January       9134.45
# February     10294.61
# March        28594.69
# April        11587.44
# May          22411.31
# June         21285.80
# July         13832.66
# August       21776.94
# September    36857.48
# October      31784.04
# November     35468.43
# December     43369.19
# Name: Profit, dtype: float64

# %%
plt.figure(figsize = (10,6))
plt.plot(each_month_profits.index,each_month_profits.values)
plt.xlabel('Months')
plt.ylabel('Profits')
plt.title('Profits For Each Month')
plt.xticks(rotation = 45)
plt.grid(True)
plt.show()

# %% [markdown]
# Question 7.2: What is the average profit margin (Profit/Sales) for each category? Visualize this using a bar chart.

# %%
super_store_df['profit_margin'] = (super_store_df['Profit'] / super_store_df['Sales'])
category_profit_margin = super_store_df.groupby('Category')['profit_margin'].mean()
category_profit_margin
# Out:
# Category
# Furniture          0.038784
# Office Supplies    0.138030
# Technology         0.156138
# Name: profit_margin, dtype: float64

# %%
plt.bar(category_profit_margin.index,category_profit_margin.values,color=['blue', 'green', 'orange'])
plt.xlabel('Category')
plt.ylabel('Average profit Margin')
plt.title('Average profit Margin for each category')
plt.show()
